# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 设置图像的显示位置，设置图像现在在当前的文档中
# %matplotlib inline

# plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']  # mac
plt.rcParams['font.sans-serif'] = 'SimHei'  # window
plt.rcParams['axes.unicode_minus'] = False  # 设置负号


# %config InlineBackend.figure_format = 'svg' #矢量图设置

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#引入数据
douyin = pd.read_csv("./douyin.csv")

# %%
douyin.head()
# Out:
#         name gender country province city location category       fans  \
# 0       人民日报      0      中国       北京   北京       北京       政企  117259000
# 1       央视新闻      0      中国       北京   北京       北京       政企  105648000
# 2         陈赫      1      中国      NaN   上海       上海       明星   68374000
# 3  Dear-迪丽热巴      0     NaN      NaN  NaN      NaN       明星   49790000
# 4       毒舌电影      1      中国       广东   广州       广州       剧情   46355000
#
#    videos       likes     comments      shares following  school  \
# 0    2427  1165446000  11906782048  9089061412        18     NaN
# 1    3681  3814571666   2603872833  1989050522        27     NaN
# 2     422   570096000    430908721   117639297       131  上海戏剧学院
# 3      29   181167000    202448645   151645265         0     NaN
# 4     616   820393000     28026109    13005392        24     NaN
#
#      custom_verify enterprise_verify  \
# 0              NaN          人民日报官方账号
# 1         央视新闻官方账号         央视新闻官方抖音号
# 2             演员陈赫               NaN
# 3               演员               NaN
# 4  优质影视自媒体、抖音影评团成员               NaN
#
#                                            signature
# 0                                        参与、沟通、记录时代。
# 1                                      本宝宝暂时还没想到个性签名
# 2       😎帅到没朋友 💁🏻‍♂️有东西直播间 🔜1⃣️1⃣️1⃣️8⃣️🕔 ☑️公众号➰[陈赫]
# 3                                                NaN
# 4  看电影， 可以改变人生。  商务邮：dsmovie@youhaoxi.cn ❤️  日历预售...

# %% [markdown]
# ### 查看大V账户的男女比例

# %%
res=douyin['gender'].value_counts()[:2]
res=res.tolist()
res
# Out:
# [2592, 2094]

# %%
data1=[['男',res[0]],['女',res[1]]]

# %%
from pyecharts.faker import Faker
[list(z) for z in zip (Faker.choose(),Faker.values())]
# Out:
# [['周一', 59],
#  ['周二', 124],
#  ['周三', 87],
#  ['周四', 22],
#  ['周五', 137],
#  ['周六', 41],
#  ['周日', 81]]

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie


(
    Pie()
    .add("",data1,
        radius=["40%", "55%"],
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 16, "lineHeight": 33},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="大v的男女比例"))
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="295a885a62944434a7d54df001f27ca2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_295a885a62944434a7d54df001f27ca2 = echarts.init(
#                     document.getElementById('295a885a62944434a7d54df001f27ca2'), 'white', {renderer: 'canvas'});
#                 var option_295a885a62944434a7d54df001f27ca2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7537",
#                     "value": 2592
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 2094
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|{a}}{abg|}\n{hr|}\n {b|{b}: }{c}  {per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5927v\u7684\u7537\u5973\u6bd4\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_295a885a62944434a7d54df001f27ca2.setOption(option_295a885a62944434a7d54df001f27ca2);
#         });
#     </script>

# %% [markdown]
# ###  看国外的主要网红来源有哪些国家

# %%
douyin['country'].unique()
# Out:
# array(['中国', nan, 'Hong Kong', '暂不设置', '阿尔及利亚', '奥地利', '百慕大', '美国',
#        '阿拉伯联合酋长国', '尼泊尔', '爱沙尼亚', '斯里兰卡', '英国', '埃塞俄比亚', '韩国', '大韩民国',
#        '埃及', '法国', '阿尔巴尼亚', '澳大利亚', 'China', '安道尔', '瑞士', '日本', '泰国',
#        '爱尔兰', '俄罗斯', 'United States', '加拿大', '巴巴多斯岛', '汤加', '阿鲁巴', '西班牙',
#        '挪威', '冰岛', '阿曼', '约旦', '安哥拉', '玻利维亚', '巴哈马', '香港', '苏丹', '直布罗陀'],
#       dtype=object)

# %%
dic={
    'China':'中国',
    'Hong Kong':'香港',
    '大韩民国':'韩国',
    'United States':'美国',
}

# %%
douyin['country']=douyin['country'].replace(dic)

# %%
res = douyin['country'].value_counts()
res[:10].plot.bar(figsize=(10,6))
plt.show()

# %% [markdown]
# ### 看国内的网红主要分布的省份、城市

# %%
douyin.columns
# Out:
# Index(['name', 'gender', 'country', 'province', 'city', 'location', 'category',
#        'fans', 'videos', 'likes', 'comments', 'shares', 'following', 'school',
#        'custom_verify', 'enterprise_verify', 'signature'],
#       dtype='object')

# %%
res=douyin[douyin['country']=='中国']
res['province'].unique()
# Out:
# array(['北京', nan, '广东', '云南', '上海', '江苏', '吉林', '湖南省', '四川', '黑龙江', '安徽',
#        '山东', '浙江', '贵州', '湖南', '浙江省', '辽宁', '新疆', '四川省', '江西', '山东省',
#        '重庆', '湖北', '河南', '福建', '广西', '山西', '湖北省', '陕西', '天津', '江苏省',
#        '广东省', '河北', '黑龙江省', '河南省', '青海', '海南', '广西壮族自治区', '福建省', '辽宁省',
#        '安徽省', '河北省', '内蒙古', '台湾', '云南省', '甘肃', '江西省', '贵州省', '新疆维吾尔自治区',
#        'Sichuan', '青海省', '海南省', '陕西省', '吉林省', '山西省', '香港', '内蒙古自治区',
#        'Jilin', '宁夏', 'Hubei', '甘肃省', 'Guangdong', 'Shaanxi'],
#       dtype=object)

# %%
dic={
    '新疆维吾尔自治区':'新疆',
    'Sichuan':'四川',
    'Jilin':'湖北',
    'Guangdong':'广东',
    'Shaanxi':'陕西',
    '内蒙古自治区':'内蒙古',
    '广西壮族自治区':'广西'
}

# %%
douyin['province'].replace(dic,inplace=True)

# %%
douyin['province'] = douyin['province'].str.rstrip("省")

# %%
res['province'].value_counts().plot.bar(figsize=(10,6))
plt.show()

# %%
res['city'].unique()
# Out:
# array(['北京', '上海', '广州', '昆明', '苏州', '延边', '岳阳市', '绵阳', '哈尔滨', '六安',
#        '重庆市', '威海', '杭州', '贵阳', '南京', '邵阳', '杭州市', '鞍山', '乌鲁木齐', '天津',
#        '成都市', '沈阳', '金华', '萍乡', '成都', '韶关', '北京市', '徐州', '长沙', '青岛',
#        '上海市', '深圳', '青岛市', '重庆', '武汉', '郑州', '天津市', '厦门', '贺州', '太原',
#        '自贡', '武汉市', '黑河', '四平', '芜湖', '西安', '福州', '镇江', '安阳', '常州市', '长春',
#        '广州市', '阿坝', '潜江', '东莞', '长沙市', '石家庄', '大连', '丽江', '怀化', '营口',
#        '香港', '南通', '哈尔滨市', '烟台', '宜宾', '绍兴', '运城', '商丘', '佛山', '鄂州', '宿迁',
#        '郴州', '深圳市', '聊城', '南阳市', '九江', '随州', '济南', '西宁', '无锡', '铜陵', '三亚',
#        '桂林市', '广安', '六盘水', '郑州市', '合肥', '福州市', '丽水', '洛阳', '大连市', '日照',
#        '合肥市', '朝阳', '泉州市', '抚顺', '保定', '伊春市', '信阳', '晋城', '厦门市', '石家庄市',
#        '铜仁', '三明', '珠海', '泰州', '佳木斯', '铁岭', '安康', '廊坊', '乐山', '嘉兴', '秦皇岛',
#        '温州市', '泸州市', '贺州市', '常德', '抚州', '宁波', '台北市', '泉州', '咸阳', '潍坊',
#        '大理白族自治州', '惠州', '陇南', '永州', '衡水', '许昌市', '包头', '内江', '商丘市', '金华市',
#        '苏州市', '淄博', '乐山市', '宜春', '莆田', '宣城', '呼和浩特', '东营市', '三门峡', '陵水',
#        '齐齐哈尔', '资阳', '海口', '连云港', '通辽', '达州', '遵义', '上饶', '南昌', '温州',
#        '南昌市', '漳州', '三门峡市', '衢州市', '邯郸', '黔南布依族苗族自治州', '锦州', '徐州市',
#        'Shanghai', '茂名', '莆田市', '宜宾市', '岳阳', '乌鲁木齐市', '枣庄', '牡丹江', '黔南',
#        '柳州', '信阳市', '沈阳市', '荆门', '张家口', '松原', '南京市', '南阳', '通化', '临沂',
#        '雅安市', '常州', '绥化', '许昌', '湘西土家族苗族自治州', 'Guangyuan', '淮安', '广元',
#        '泸州', '本溪', '宿州', '潍坊市', '丹东', '高雄市', '西宁市', '淮北市', '驻马店', '菏泽',
#        '阿尔汉格尔斯克', '邯郸市', '宁德', '洛阳市', '营口市', '沧州', '恩施土家族苗族自治州', '克孜勒苏',
#        '淄博市', '湖州', '宁波市', '龙岩', '济南市', '河源', '邢台', '玉林', '三亚市', '襄阳',
#        '河源市', 'Cebu City', '昌吉', '汉中市', '盘锦', '株洲', '江门', '南宁', '白城市',
#        '焦作', '威海市', '曲靖市', '安庆', '娄底市', '太原市', '阳江', '台州', '运城市', '赣州市',
#        '商洛', '梅州市', '南平', '张家界', '鄂尔多斯', '新界', '贵港', '荆州市', '阿克苏', '新余',
#        '遂宁', '十堰', '衡阳', '呼伦贝尔市', '吉安', '德州', '舟山', '大理', 'Changchun',
#        '宿迁市', '益阳市', '澄迈', '扬州', '临汾', '荆州', '济宁', '黄山', '宜昌', '眉山市',
#        '松原市', '台北', '梅州', '连云港市', '石嘴山', '吉林', '眉山', '亳州', '朔州', '宜昌市',
#        '鹤壁', '保定市', '宿州市', '晋中', '赣州', '西安市', '临汾市', '凉山', '烟台市', '宁德市',
#        '东莞市', '六安市', '汕头', '海口市', '蚌埠', '南宁市', '阜阳', '达州市', '新乡', '遂宁市',
#        '珠海市', '平顶山', '惠州市', '承德', '澳门', '安顺', '佳木斯市', '绍兴市', '桂林', '菏泽市',
#        '锡林郭勒', '枣庄市', 'Wuhan', '南通市', '赤峰', '济宁市', '揭阳', '濮阳市', '盐城',
#        '九龙', '自贡市', '濮阳', '长治', '南充市', '克拉玛依', 'Beijing', '开封市', nan,
#        '临夏', '梧州', '唐山', '内江市', '新北', '廊坊市', '黔东南', '七台河', '武威', '鞍山市',
#        '呼和浩特市', '白山', '昆明市', '长春市', '盘锦市', '铜川', '伊春', '香港岛', '白银市', '昭通',
#        '渭南', '辽阳市', '吉林市', '孝感', '通化市', '扬州市', '玉溪', '马鞍山', '漳州市',
#        'Guangzhou', '娄底', '黔西南', '南充', '滁州', '伊犁', '湛江', '咸宁', '衢州', '忻州',
#        '孝感市', '巴中', '邢台市', '大庆', '淮南', '德阳', '大庆市', "Xi'an", '攀枝花', '文昌',
#        '新竹', '葫芦岛', '中山', '滨州市', '阳泉', '东营', '普洱市', '保山', '滨州', '雅安',
#        '周口', '遵义市', '承德市', '白城', '漯河', '湖北省', '平凉', '德宏', '双鸭山', '毕节',
#        '潮州', '北海', '兰州', '鹤壁市', '石河子', '景德镇', '呼伦贝尔', '钦州市', '榆林市', '开封',
#        '临沂市', '阜新', '吐鲁番', '甘孜', '本溪市', '日照市', '渭南市', '淮安市', '云浮'],
#       dtype=object)

# %%
res.loc[:,'city']=res['city'].str.rstrip('市')

# %%
res['city'].unique()
# Out:
# array(['北京', '上海', '广州', '昆明', '苏州', '延边', '岳阳', '绵阳', '哈尔滨', '六安', '重庆',
#        '威海', '杭州', '贵阳', '南京', '邵阳', '鞍山', '乌鲁木齐', '天津', '成都', '沈阳', '金华',
#        '萍乡', '韶关', '徐州', '长沙', '青岛', '深圳', '武汉', '郑州', '厦门', '贺州', '太原',
#        '自贡', '黑河', '四平', '芜湖', '西安', '福州', '镇江', '安阳', '常州', '长春', '阿坝',
#        '潜江', '东莞', '石家庄', '大连', '丽江', '怀化', '营口', '香港', '南通', '烟台', '宜宾',
#        '绍兴', '运城', '商丘', '佛山', '鄂州', '宿迁', '郴州', '聊城', '南阳', '九江', '随州',
#        '济南', '西宁', '无锡', '铜陵', '三亚', '桂林', '广安', '六盘水', '合肥', '丽水', '洛阳',
#        '日照', '朝阳', '泉州', '抚顺', '保定', '伊春', '信阳', '晋城', '铜仁', '三明', '珠海',
#        '泰州', '佳木斯', '铁岭', '安康', '廊坊', '乐山', '嘉兴', '秦皇岛', '温州', '泸州', '常德',
#        '抚州', '宁波', '台北', '咸阳', '潍坊', '大理白族自治州', '惠州', '陇南', '永州', '衡水',
#        '许昌', '包头', '内江', '淄博', '宜春', '莆田', '宣城', '呼和浩特', '东营', '三门峡',
#        '陵水', '齐齐哈尔', '资阳', '海口', '连云港', '通辽', '达州', '遵义', '上饶', '南昌',
#        '漳州', '衢州', '邯郸', '黔南布依族苗族自治州', '锦州', 'Shanghai', '茂名', '枣庄',
#        '牡丹江', '黔南', '柳州', '荆门', '张家口', '松原', '通化', '临沂', '雅安', '绥化',
#        '湘西土家族苗族自治州', 'Guangyuan', '淮安', '广元', '本溪', '宿州', '丹东', '高雄',
#        '淮北', '驻马店', '菏泽', '阿尔汉格尔斯克', '宁德', '沧州', '恩施土家族苗族自治州', '克孜勒苏',
#        '湖州', '龙岩', '河源', '邢台', '玉林', '襄阳', 'Cebu City', '昌吉', '汉中', '盘锦',
#        '株洲', '江门', '南宁', '白城', '焦作', '曲靖', '安庆', '娄底', '阳江', '台州', '赣州',
#        '商洛', '梅州', '南平', '张家界', '鄂尔多斯', '新界', '贵港', '荆州', '阿克苏', '新余',
#        '遂宁', '十堰', '衡阳', '呼伦贝尔', '吉安', '德州', '舟山', '大理', 'Changchun',
#        '益阳', '澄迈', '扬州', '临汾', '济宁', '黄山', '宜昌', '眉山', '石嘴山', '吉林', '亳州',
#        '朔州', '鹤壁', '晋中', '凉山', '汕头', '蚌埠', '阜阳', '新乡', '平顶山', '承德', '澳门',
#        '安顺', '锡林郭勒', 'Wuhan', '赤峰', '揭阳', '濮阳', '盐城', '九龙', '长治', '南充',
#        '克拉玛依', 'Beijing', '开封', nan, '临夏', '梧州', '唐山', '新北', '黔东南', '七台河',
#        '武威', '白山', '铜川', '香港岛', '白银', '昭通', '渭南', '辽阳', '孝感', '玉溪', '马鞍山',
#        'Guangzhou', '黔西南', '滁州', '伊犁', '湛江', '咸宁', '忻州', '巴中', '大庆', '淮南',
#        '德阳', "Xi'an", '攀枝花', '文昌', '新竹', '葫芦岛', '中山', '滨州', '阳泉', '普洱',
#        '保山', '周口', '漯河', '湖北省', '平凉', '德宏', '双鸭山', '毕节', '潮州', '北海', '兰州',
#        '石河子', '景德镇', '钦州', '榆林', '阜新', '吐鲁番', '甘孜', '云浮'], dtype=object)

# %%
dic1={
    'Shanghai':'上海',
    'Guangyuan':'广元',
    'Changchun':'长春',
    'Wuhan':'武汉',
    'Beijing':'北京',
    'Guangzhou':'广州',
    "Xi'an":'西安',
}

# %%
res['city'].replace(dic1,inplace=True)

# %% [markdown]
# ### 看大V喜欢什么类别的视频

# %%
douyin.columns
# Out:
# Index(['name', 'gender', 'country', 'province', 'city', 'location', 'category',
#        'fans', 'videos', 'likes', 'comments', 'shares', 'following', 'school',
#        'custom_verify', 'enterprise_verify', 'signature'],
#       dtype='object')

# %%
douyin['category'].value_counts()[:10].plot.bar(figsize=(10,6))
plt.show()

# %% [markdown]
# ### 大V的粉丝数的分布 主要的粉丝量是多少

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.histplot(x=douyin['fans']/1e6,bins=[0,1,3,5,10,20,50,100,200])
plt.xticks([0,1,3,5,10,20,50,100,200])
plt.show()

# %%
data = pd.cut(x=v.fans.values,bins=[0,500000,1000000,2000000,5000000,10000000,100000000],
              labels=['0--50万','50-100万','100-200万','200-500万','500-1000万','1000万以上'])
data.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 发布最多的视频的抖音账号是哪些?TOP10

# %%
videos = douyin.groupby('name')[['videos']].sum()
videos.sort_values('videos',ascending=False,inplace=True)

# %% [markdown]
# ### 查看哪些大V获取的点赞数更多？

# %%
.sort_values(by="likes",ascending=False)[["name",'likes']].set_index("name")[:10].plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 v.sort_values(by="likes",ascending=False)[["name",'likes']].set_index("name")[:10].plot(kind="bar")
#
# NameError: name 'v' is not defined

# %% [markdown]
# ### 查看点赞数量的分布

# %%
pd.pivot_table(df,
              index='city',
              values='likes',
              aggfunc='sum').nlargest(15,'likes').plot.pie(subplots=True,figsize=(6,6),autopct="%.1f%%")
# Out:
# array([<AxesSubplot:ylabel='likes'>], dtype=object)

# %% [markdown]
# ### 查看评论、分享的分布

# %%
df.groupby('city')[['comments','shares']].sum()

pd.pivot_table(df,
              index='province',
              aggfunc='sum').nlargest(15,'fans')[['comments','shares']].plot.pie(subplots=True,figsize=(6,6),autopct="%.1f%%")
# Out:
# array([<AxesSubplot:ylabel='comments'>, <AxesSubplot:ylabel='shares'>],
#       dtype=object)

# %% [markdown]
# ### 查看大V的毕业院校主要是哪些

# %%
douyin.groupby('school').sum().nlargest(10,'fans')[['fans']].plot.pie(subplots=True,figsize=(6,6),autopct="%.1f%%")
# Out:
# array([<AxesSubplot:ylabel='fans'>], dtype=object)

# %%
douyin[douyin['school']!='已毕业']['school'].value_counts()[:10].plot.bar(figsize=(10,6))
# Out:
# <AxesSubplot:>
